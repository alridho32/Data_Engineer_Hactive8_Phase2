# %% [markdown]
# # Phase 2 - Week 1 - Day 2 AM - Training Artificial Neural Network: Part 1

# %% [markdown]
# **The purpose of this notebook is to demonstrate the effect of selecting the sigmoid activation function so that a vanishing gradient occurs.**
#
# Then an experiment will be carried out if the activation function is changed to ReLU.

# %% [markdown]
# The vanishing gradient problem occurs when gradients (slopes) during backpropagation **become extremely small** as they are propagated backward through the layers of a deep neural network.
#
# When gradients are very small, the updates to the network's parameters become negligible, leading to slow or stalled training.
#
# The vanishing gradient problem is typically caused by activation functions like the sigmoid or hyperbolic tangent (tanh) functions, which squash input values into a small range (e.g., between 0 and 1 or -1 and 1). When these functions are repeatedly applied in deep networks, gradients can shrink to near-zero values.
#
# As a result, deep layers of the network fail to learn meaningful representations from the data, and the network may not converge to a good solution.
#
# **The model weights can become 0 in the training phase.**

# %% [markdown]
# # A. Import Libraries & Data Loading

# %%
# Downgrade version of TensorFlow and tf-keras

# !pip install -q --upgrade "tensorflow<2.16" "tf-keras<2.16"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.3 MB/s eta 0:00:00

# %% [markdown]
# In this experiment, we will create an artificial dataset regarding Binary Classification

# %%
# Import Libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

from tensorflow.keras import Sequential
from tensorflow.keras.initializers import RandomNormal, HeNormal
from tensorflow.keras.layers import Input, Dense

# Check TensorFlow version
print(tf.__version__)
# Out:
# 2.15.1

# %%
# Make Dataset

X, y = make_circles(n_samples=1000, factor=0.5, noise=0.1)

plt.figure(figsize=(8,6))
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
# Data Splitting

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)
print('Train size : ', X_train.shape)
print('Test size  : ', X_test.shape)
# Out:
# Train size :  (850, 2)
# Test size  :  (150, 2)

# %% [markdown]
# # B. Model with Sigmoid

# %% [markdown]
# For first model, we will create an ANN model with configuration :
#
# * 2 input neuron (based on the number of features)
# * 5 layer : 1 Input, 3 Hidden Layer, 1 Output Layer
# * Each hidden layer will contains 5 hidden neurons
# * Weight Initialization : Random Normal
# * Loss function : Binary Cross Entropy
# * Optimizer : Adam

# %%
# Create ANN Model

seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

initializer = RandomNormal(mean=0, stddev=1, seed=seed)
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()

model_sigmoid = Sequential([
    Input(shape=(2,), name='input-layer'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-1'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-2'),
    Dense(5, activation='sigmoid', kernel_initializer=initializer, name='hidden-layer-3'),
    Dense(1, activation="sigmoid", kernel_initializer=initializer, name='output-layer')
])

# Compile
model_sigmoid.compile(loss=loss_function, optimizer=optimizer, metrics=['accuracy'])
model_sigmoid.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden-layer-1 (Dense)      (None, 5)                 15
#
#  hidden-layer-2 (Dense)      (None, 5)                 30
#
#  hidden-layer-3 (Dense)      (None, 5)                 30
#
#  output-layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 81 (324.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the ANN Model

model_sigmoid.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 4s 4ms/step - loss: 0.7003 - accuracy: 0.4988
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6973 - accuracy: 0.4988
# Epoch 3/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6953 - accuracy: 0.4988
# Epoch 4/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6947 - accuracy: 0.4106
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6942 - accuracy: 0.3718
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6940 - accuracy: 0.4035
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.5024
# Epoch 8/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.4965
# Epoch 9/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6937 - accuracy: 0.4965
# Epoch 10/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.5035
# Epoch 11/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.5235
# Epoch 12/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6937 - accuracy: 0.5047
# Epoch 13/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6936 - accuracy: 0.5176
# Epoch 14/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.5200
# Epoch 15/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.5635
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6936 - accuracy: 0.5400
# Epoch 17/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.5365
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6934 - accuracy: 0.5882
# Epoch 19/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.5682
# Epoch 20/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.5282
# Epoch 21/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.5435
# Epoch 22/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5212
# Epoch 23/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6932 - accuracy: 0.5424
# Epoch 24/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5071
# Epoch 25/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5259
# Epoch 26/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.5176
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.4871
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.5224
# Epoch 29/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.5541
# Epoch 30/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.5224
# Epoch 31/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.5341
# Epoch 32/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5212
# Epoch 33/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5694
# Epoch 34/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6927 - accuracy: 0.5765
# Epoch 35/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6925 - accuracy: 0.5376
# Epoch 36/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6925 - accuracy: 0.5306
# Epoch 37/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.5141
# Epoch 38/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.5553
# Epoch 39/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.6059
# Epoch 40/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6923 - accuracy: 0.6059
# Epoch 41/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.5129
# Epoch 42/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6923 - accuracy: 0.5224
# Epoch 43/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6921 - accuracy: 0.5612
# Epoch 44/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6922 - accuracy: 0.5341
# Epoch 45/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6924 - accuracy: 0.6059
# Epoch 46/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6919 - accuracy: 0.5635
# Epoch 47/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6919 - accuracy: 0.5365
# Epoch 48/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6918 - accuracy: 0.5671
# Epoch 49/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6921 - accuracy: 0.5282
# Epoch 50/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.5729
# Epoch 51/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6918 - accuracy: 0.6106
# Epoch 52/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6914 - accuracy: 0.5612
# Epoch 53/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6913 - accuracy: 0.5506
# Epoch 54/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6912 - accuracy: 0.5718
# Epoch 55/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6912 - accuracy: 0.5529
# Epoch 56/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.5682
# Epoch 57/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6910 - accuracy: 0.5553
# Epoch 58/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6910 - accuracy: 0.5376
# Epoch 59/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5482
# Epoch 60/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5553
# Epoch 61/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6905 - accuracy: 0.5906
# Epoch 62/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6904 - accuracy: 0.5659
# Epoch 63/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.5682
# Epoch 64/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6900 - accuracy: 0.5682
# Epoch 65/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6899 - accuracy: 0.5682
# Epoch 66/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6898 - accuracy: 0.5529
# Epoch 67/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6896 - accuracy: 0.5518
# Epoch 68/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6895 - accuracy: 0.5565
# Epoch 69/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6893 - accuracy: 0.5671
# Epoch 70/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6891 - accuracy: 0.5588
# Epoch 71/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6890 - accuracy: 0.5918
# Epoch 72/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6887 - accuracy: 0.5682
# Epoch 73/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6885 - accuracy: 0.5576
# Epoch 74/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.5553
# Epoch 75/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6882 - accuracy: 0.5494
# Epoch 76/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6878 - accuracy: 0.5576
# Epoch 77/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.5600
# Epoch 78/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6873 - accuracy: 0.5565
# Epoch 79/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6870 - accuracy: 0.5576
# Epoch 80/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6868 - accuracy: 0.5565
# Epoch 81/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5565
# Epoch 82/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6862 - accuracy: 0.5588
# Epoch 83/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6859 - accuracy: 0.5671
# Epoch 84/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6856 - accuracy: 0.5682
# Epoch 85/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6853 - accuracy: 0.5624
# Epoch 86/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6849 - accuracy: 0.5635
# Epoch 87/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.5612
# Epoch 88/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6843 - accuracy: 0.5682
# Epoch 89/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6841 - accuracy: 0.5847
# Epoch 90/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.5706
# Epoch 91/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6831 - accuracy: 0.5776
# Epoch 92/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6827 - accuracy: 0.5706
# Epoch 93/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6825 - accuracy: 0.5894
# Epoch 94/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6819 - accuracy: 0.5718
# Epoch 95/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6815 - accuracy: 0.5741
# Epoch 96/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6811 - accuracy: 0.5847
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.5965
# Epoch 98/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.5694
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6796 - accuracy: 0.5647
# Epoch 100/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.5741

# %%
# Predict test-set

model_sigmoid.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6833 - accuracy: 0.5533
# [0.6833158731460571, 0.5533333420753479]

# %% [markdown]
# Unfortunately, the performance of the model using the sigmoid is too low when tested with a test-set. The accuracy value only reaches 58 %.

# %% [markdown]
# # C. Model with ReLU

# %% [markdown]
# Let's improve our model by changing :
#
# * The activation function to ReLU
# * Weight initialization to HeNormal (HeNormal is more suitable for use by ReLU for weight initialization techniques).

# %%
# Create ANN Model

seed = 20
tf.keras.backend.clear_session()
np.random.seed(seed)
tf.random.set_seed(seed)

initializer = HeNormal(seed=seed)
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()

model_relu = Sequential([
    Input(shape=(2,), name='input-layer'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-1'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-2'),
    Dense(5, activation='relu', kernel_initializer=initializer, name='hidden-layer-3'),
    Dense(1, activation="sigmoid", kernel_initializer=initializer, name='output-layer')
])

# Compile
model_relu.compile(loss=loss_function,
              optimizer=optimizer,
              metrics=['accuracy'])
model_relu.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden-layer-1 (Dense)      (None, 5)                 15
#
#  hidden-layer-2 (Dense)      (None, 5)                 30
#
#  hidden-layer-3 (Dense)      (None, 5)                 30
#
#  output-layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 81 (324.00 Byte)
# Trainable params: 81 (324.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the ANN Model

model_relu.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 4ms/step - loss: 0.7974 - accuracy: 0.4824
# Epoch 2/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.7460 - accuracy: 0.4929
# Epoch 3/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.7173 - accuracy: 0.4718
# Epoch 4/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.4612
# Epoch 5/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6825 - accuracy: 0.4494
# Epoch 6/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.4576
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6552 - accuracy: 0.5224
# Epoch 8/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6427 - accuracy: 0.5576
# Epoch 9/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6298 - accuracy: 0.5812
# Epoch 10/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6168 - accuracy: 0.6035
# Epoch 11/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6045 - accuracy: 0.6212
# Epoch 12/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5918 - accuracy: 0.6400
# Epoch 13/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5793 - accuracy: 0.6612
# Epoch 14/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5660 - accuracy: 0.6941
# Epoch 15/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5539 - accuracy: 0.7271
# Epoch 16/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5412 - accuracy: 0.7400
# Epoch 17/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5296 - accuracy: 0.7529
# Epoch 18/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.7706
# Epoch 19/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.7788
# Epoch 20/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.7859
# Epoch 21/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4853 - accuracy: 0.8024
# Epoch 22/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4732 - accuracy: 0.8059
# Epoch 23/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.4604 - accuracy: 0.8188
# Epoch 24/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4451 - accuracy: 0.8247
# Epoch 25/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.8388
# Epoch 26/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4171 - accuracy: 0.8506
# Epoch 27/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4041 - accuracy: 0.8576
# Epoch 28/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8671
# Epoch 29/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3774 - accuracy: 0.8765
# Epoch 30/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3645 - accuracy: 0.8894
# Epoch 31/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3513 - accuracy: 0.8953
# Epoch 32/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3385 - accuracy: 0.9024
# Epoch 33/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.3229 - accuracy: 0.9118
# Epoch 34/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2995 - accuracy: 0.9235
# Epoch 35/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2690 - accuracy: 0.9400
# Epoch 36/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2419 - accuracy: 0.9518
# Epoch 37/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2188 - accuracy: 0.9694
# Epoch 38/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.2010 - accuracy: 0.9729
# Epoch 39/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9741
# Epoch 40/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1704 - accuracy: 0.9800
# Epoch 41/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1569 - accuracy: 0.9824
# Epoch 42/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1455 - accuracy: 0.9824
# Epoch 43/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1339 - accuracy: 0.9835
# Epoch 44/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.9835
# Epoch 45/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1146 - accuracy: 0.9847
# Epoch 46/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 0.9882
# Epoch 47/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9882
# Epoch 48/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0921 - accuracy: 0.9894
# Epoch 49/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0864 - accuracy: 0.9871
# Epoch 50/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0807 - accuracy: 0.9894
# Epoch 51/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0763 - accuracy: 0.9894
# Epoch 52/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0725 - accuracy: 0.9894
# Epoch 53/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0682 - accuracy: 0.9894
# Epoch 54/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0650 - accuracy: 0.9882
# Epoch 55/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0618 - accuracy: 0.9882
# Epoch 56/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0590 - accuracy: 0.9882
# Epoch 57/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0570 - accuracy: 0.9882
# Epoch 58/100
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0542 - accuracy: 0.9882
# Epoch 59/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0524 - accuracy: 0.9882
# Epoch 60/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0505 - accuracy: 0.9882
# Epoch 61/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0485 - accuracy: 0.9871
# Epoch 62/100
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0469 - accuracy: 0.9906
# Epoch 63/100
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0455 - accuracy: 0.9882
# Epoch 64/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0442 - accuracy: 0.9871
# Epoch 65/100
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0436 - accuracy: 0.9906
# Epoch 66/100
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0422 - accuracy: 0.9882
# Epoch 67/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0410 - accuracy: 0.9894
# Epoch 68/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 0.9882
# Epoch 69/100
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0393 - accuracy: 0.9894
# Epoch 70/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0385 - accuracy: 0.9894
# Epoch 71/100
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 0.9906
# Epoch 72/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9894
# Epoch 73/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0369 - accuracy: 0.9871
# Epoch 74/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.9871
# Epoch 75/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 0.9906
# Epoch 76/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9906
# Epoch 77/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9882
# Epoch 78/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 0.9894
# Epoch 79/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 0.9906
# Epoch 80/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9882
# Epoch 81/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9894
# Epoch 82/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9894
# Epoch 83/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 0.9894
# Epoch 84/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9894
# Epoch 85/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 0.9894
# Epoch 86/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9906
# Epoch 87/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 0.9906
# Epoch 88/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9906
# Epoch 89/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 0.9906
# Epoch 90/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0287 - accuracy: 0.9906
# Epoch 91/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9906
# Epoch 92/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 0.9918
# Epoch 93/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9918
# Epoch 94/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9918
# Epoch 95/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9918
# Epoch 96/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9918
# Epoch 97/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9906
# Epoch 98/100
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9929
# Epoch 99/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9918
# Epoch 100/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9918

# %%
# Predict test-set

model_relu.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0198 - accuracy: 1.0000
# [0.019766157492995262, 1.0]

# %% [markdown]
# After changing the activation function and weight initialization, it can be seen that the performance of the train and test has increased drastically, even approaching perfect conditions. Hooray.

# %% [markdown]
# # D. The Gradient

# %% [markdown]
# Let's look at the gradient differences between models that use the Sigmoid activation function with ReLU. Let's prove whether it is true that the Sigmoid activation function leads to a vanish gradient or not.

# %%
# Create a Function to Store Weights from Each Epoch

def train_model(X, y, model, loss_function, optimizer, n_epochs=100, batch_size=32):
    "Run training loop manually"
    train_dataset = tf.data.Dataset.from_tensor_slices((X, y))
    train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

    gradhistory = []
    losshistory = []
    def recordweight():
        data = {}
        for g,w in zip(grads, model.trainable_weights):
            if '/kernel:' not in w.name:
                continue # skip bias
            name = w.name.split("/")[0]
            data[name] = g.numpy()
        gradhistory.append(data)
        losshistory.append(loss_value.numpy())
    for epoch in range(n_epochs):
        for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
            with tf.GradientTape() as tape:
                y_pred = model(x_batch_train, training=True)
                loss_value = loss_function(y_batch_train, y_pred)

            grads = tape.gradient(loss_value, model.trainable_weights)
            optimizer.apply_gradients(zip(grads, model.trainable_weights))

            if step == 0:
                recordweight()

    recordweight()
    return gradhistory, losshistory

# %%
# Create a Function to Plot the Gradients of Each Epoch

def plot_gradient(gradhistory, losshistory):
    "Plot gradient mean and sd across epochs"
    fig, ax = plt.subplots(1, 3, sharex=True, constrained_layout=True, figsize=(15, 4))
    ax[0].set_title("Mean gradient")
    for key in gradhistory[0]:
        ax[0].plot(range(len(gradhistory)), [w[key].mean() for w in gradhistory], label=key)
    ax[0].legend()
    ax[1].set_title("S.D.")
    for key in gradhistory[0]:
        ax[1].semilogy(range(len(gradhistory)), [w[key].std() for w in gradhistory], label=key)
    ax[1].legend()
    ax[2].set_title("Loss")
    ax[2].plot(range(len(losshistory)), losshistory)
    plt.show()

# %%
# Check the Gradients on Sigmoid Model and ReLU Model

# %%time
loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()
gradhistory_sigmoid, losshistory_sigmoid = train_model(X_train, y_train, model_sigmoid, loss_function, optimizer, n_epochs=100, batch_size=32)

loss_function = tf.keras.losses.BinaryCrossentropy()
optimizer = tf.keras.optimizers.Adam()
gradhistory_relu, losshistory_relu = train_model(X_train, y_train, model_relu, loss_function, optimizer, n_epochs=100, batch_size=32)

print('-- Sigmoid Model -- ')
plot_gradient(gradhistory_sigmoid, losshistory_sigmoid)
print('')

print('-- ReLU Model -- ')
plot_gradient(gradhistory_relu, losshistory_relu)
print('')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7b581bffaef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7b581bffaef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# -- Sigmoid Model --
# -- ReLU Model --
# CPU times: user 1min 58s, sys: 1.75 s, total: 1min 59s
# Wall time: 2min 10s

# %% [markdown]
# **INSIGHTS :**
#
# 1. Sigmoid model :
#    * From the `Mean gradient` plot, it can be seen that only the gradients from the output layer has a fluctuating gradient.
#    * While the gradient of the other layers is around `0`.
#    * This causes the the loss value decreases slowly and even looks stagnant. This phenomenon is called vanishing gradient.
#
# 2. ReLU model :
#    * The gradient that comes from the ReLU model varies in each layer and tends to go up and down so it doesn't stagnate at `0`.
#    * This causes the loss values to change, allowing the model to reach its optimal point.
